# %%
# !pip install colabturtleplus

# %%
from ColabTurtlePlus.Turtle import *

clearscreen()

#Draw a square

#draw the 4 sides
forward(50)
right(90)

forward(50)
right(90)

forward(50)
right(90)

forward(50)
right(90)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="450.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="450.0" y1="300.0" x2="450.0" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="450.0" y1="350.0" x2="400.0" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="400.0" y1="350.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(180,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
# ...

# %%
from ColabTurtlePlus.Turtle import *

#draw a square
clearscreen()
angle = 90
length = 50

for i in range(4):
  #draw a line and rotate
  forward(length)
  right(angle)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="450.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="450.0" y1="300.0" x2="450.0" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="450.0" y1="350.0" x2="400.0" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="400.0" y1="350.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(180,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
# ...

# %%
from ColabTurtlePlus.Turtle import *

#draw a regular polygon
clearscreen()
sides = 8
angle = 360 / sides
length = 15


for i in range(sides):
  #draw a line and rotate
  forward(length)
  right(angle)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %%
#python keywords

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Python Data Types
#
# ## Type conversion test
#
# Before running this code, try to guess the result, see how many you get correct

# %%
#examples of int, float, bool, and str
#uncomment each line to run (remove the leading #)


#int conversions
#print(int(4)) #convert int to int
#print(int(4.2)) #convert float to int
#print(int("123")) #convert str to int
#print(int("4.2")) #convert str to int
#print(int("hello"))# convert str to int
#print(int(True)) #convert boolean to int
#print(int("True")) #convert str to int

#float conversions
#print(float(4.2)) #convert float to float
#print(float(4)) #convert int to float
#print(float("4.2")) #convert str to float
#print(float("4")) #convert str to float
#print(float(True)) #convert bool to float
#print(float("True")) #convert str to float

#str conversions
#print(str("hello")) #convert str to str
#print(str(hello)) #convert name to str
#print(str(4)) #convert int to str
#print(str(4.2)) #convert float to str
#print(str(True)) #convert bool to str
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-14-3011022582.py in <cell line: 0>()
#       1 #examples of int, float, bool, and str
#       2
# ----> 3 int ("hello")
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
# Try at home Hering Illusion in ColabTurtle
# Refactor this code to use variables and loops and expand it to draw many more spokes than 4
# last day's code

# hering Illusion in Turtle Draw

from ColabTurtlePlus.Turtle import *

clearscreen()

#draw the spokes
forward(100)
backward(100)
right(90)
forward(100)
backward(100)
right(90)
forward(100)
backward(100)
right(90)
forward(100)
backward(100)

#align for first parallel line
penup()
right(90)
forward(25)
left(90)

#change the color
#RGB
color(255, 0, 0)

forward(100)
pendown()
backward(200)

#align for second parallel line
penup()
left(90)
forward(50)
right(90)
pendown()
forward(200)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %%
# Try at home, improve this code by using variables to make it more readable
# can you make it so it is easy to scale the E to larger or smaller sizes?

#draw a block letter capitol E

from ColabTurtlePlus.Turtle import *

clearscreen()

#move the turtle to better starting location
penup()
left(90)
pendown()

speed(7)

#start drawing the turtle
right(90)
forward(120)
right(90)
forward(20)
right(90)
forward(100)
left(90)
forward(40)
left(90)
forward(80)
right(90)
forward(20)
right(90)
forward(80)
left(90)
forward(40)
left(90)
forward(100)
right(90)
forward(20)
right(90)
forward(120)
right(90)
forward(140)


hideturtle()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...
